#      ---------------- ------------------- 450.6/987.4 kB 271.0 kB/s eta 0:00:02
#      ----------------- ------------------ 481.3/987.4 kB 281.9 kB/s eta 0:00:02
#      ------------------ ----------------- 512.0/987.4 kB 289.4 kB/s eta 0:00:02
#      ------------------- ---------------- 532.5/987.4 kB 295.9 kB/s eta 0:00:02
#      -------------------- --------------- 563.2/987.4 kB 305.2 kB/s eta 0:00:02
#      --------------------- -------------- 593.9/987.4 kB 311.3 kB/s eta 0:00:02
#      ---------------------- ------------- 614.4/987.4 kB 317.0 kB/s eta 0:00:02
#      ----------------------- ------------ 655.4/987.4 kB 330.3 kB/s eta 0:00:02
#      --------------------------- -------- 757.8/987.4 kB 371.0 kB/s eta 0:00:01
#      ------------------------------- ---- 860.2/987.4 kB 412.2 kB/s eta 0:00:01
#      ---------------------------------- - 942.1/987.4 kB 445.2 kB/s eta 0:00:01
#      ------------------------------------ 987.4/987.4 kB 456.6 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting google-api-python-client>=1.2 (from pydrive)
#   Obtaining dependency information for google-api-python-client>=1.2 from https://files.pythonhosted.org/packages/8a/b6/8a078928c6878d4097ece3b293940d2be6d06e7151fe9667ff50adb0968e/google_api_python_client-2.99.0-py2.py3-none-any.whl.metadata
#   Downloading google_api_python_client-2.99.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting oauth2client>=4.0.0 (from pydrive)
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      ---------------------------------------- 0.0/98.2 kB ? eta -:--:--
#      ---------------------------------------- 98.2/98.2 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=3.0 in c:\users\juanj\anaconda3\lib\site-packages (from pydrive) (6.0)
# Collecting httplib2<1.dev0,>=0.15.0 (from google-api-python-client>=1.2->pydrive)
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#      ---------------- --------------------- 41.0/96.9 kB 991.0 kB/s eta 0:00:01
#      ---------------------------------------- 96.9/96.9 kB 1.1 MB/s eta 0:00:00
# Collecting google-auth<3.0.0.dev0,>=1.19.0 (from google-api-python-client>=1.2->pydrive)
#   Obtaining dependency information for google-auth<3.0.0.dev0,>=1.19.0 from https://files.pythonhosted.org/packages/9d/44/5a992cb9d7bf8aaae73bc5adaf721ad08731c9d00c1c17999a8691404b0c/google_auth-2.23.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.23.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting google-auth-httplib2>=0.1.0 (from google-api-python-client>=1.2->pydrive)
#   Obtaining dependency information for google-auth-httplib2>=0.1.0 from https://files.pythonhosted.org/packages/d3/3d/e4991229886c0d522d9552151a43ff7adcc61e026e60ce8bd508387f84cf/google_auth_httplib2-0.1.1-py2.py3-none-any.whl.metadata
#   Downloading google_auth_httplib2-0.1.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client>=1.2->pydrive)
#   Obtaining dependency information for google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 from https://files.pythonhosted.org/packages/6e/c4/c3cd048b6cbeba8d9ae50dd7643ac065b85237338aa7501b0efae91eb4d9/google_api_core-2.11.1-py3-none-any.whl.metadata
#   Downloading google_api_core-2.11.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.2->pydrive)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\juanj\anaconda3\lib\site-packages (from oauth2client>=4.0.0->pydrive) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\juanj\anaconda3\lib\site-packages (from oauth2client>=4.0.0->pydrive) (0.2.8)
# Collecting rsa>=3.1.4 (from oauth2client>=4.0.0->pydrive)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied
#   Building wheel for pydrive (setup.py): started
#   Building wheel for pydrive (setup.py): finished with status 'done'
#   Created wheel for pydrive: filename=PyDrive-1.3.1-py3-none-any.whl size=27464 sha256=953e3363ccc2e41762eb83693b4396ba919df676b7af787bb6d2dba5813ec78d
#   Stored in directory: c:\users\juanj\appdata\local\pip\cache\wheels\31\d5\09\88865e0059104686eb8365ca1d36a8b27deef34232c3b62c90
# Successfully built pydrive
# Installing collected packages: uritemplate, rsa, protobuf, httplib2, cachetools, oauth2client, googleapis-common-protos, google-auth, google-auth-httplib2, google-api-core, google-api-python-client, pydrive
# Successfully installed cachetools-5.3.1 google-api-core-2.11.1 google-api-python-client-2.99.0 google-auth-2.23.0 google-auth-httplib2-0.1.1 googleapis-common-protos-1.60.0 httplib2-0.22.0 oauth2client-4.1.3 protobuf-4.24.3 pydrive-1.3.1 rsa-4.9 uritemplate-4.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import phonenumbers as pn
from phonenumbers import geocoder
import pycountry  
from phonenumbers.phonenumberutil import region_code_for_number
from pymongo.collection import Collection
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime


import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output

# %%
uri = "mongodb+srv://diego_pontello:qEzcrA1o0rpaw6uM@transcribeme.rletx0y.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Selecciona la base de datos y la colección
db = client['TranscribeMe']
collection = db.calls

# Define el pipeline de agregación
pipeline = [
    {
        '$match': {
            'localdate': {
                '$gte': '2023-07-18',
                '$lt': '2023-09-17'
            }
        }
    },
    
    {
        "$group": {
            "_id": "$localdate",
            "user_ids": {"$addToSet": "$user_id"}
        }
    }
]

# Aplica el pipeline de agregación y obtén el resultado
result = list(collection.aggregate(pipeline))

# %%
df_dau_all = pd.DataFrame(result)

# %%
df_dau_all=df_dau_all.rename(columns={'_id' :'date'})

# %%
df_dau_all = df_dau_all.explode('user_ids')
df_dau_all['FormatedPhone']='+' + df_dau_all['user_ids'].astype(str)

# %%
df_dau_all['Country'] = df_dau_all['FormatedPhone'].apply(getCountry)

# %%
df_dau_all
# Out:
#           date       user_ids   FormatedPhone        Country
# 0   2023-09-13    59892016927    +59892016927        Uruguay
# 0   2023-09-13    12022003004    +12022003004  United States
# 0   2023-09-13   212713330362   +212713330362        Morocco
# 0   2023-09-13    34630463896    +34630463896          Spain
# 0   2023-09-13   212767715062   +212767715062        Morocco
# ..         ...            ...             ...            ...
# 60  2023-07-23  5492615183384  +5492615183384      Argentina
# 60  2023-07-23  5493516280526  +5493516280526      Argentina
# 60  2023-07-23    34661260789    +34661260789          Spain
# 60  2023-07-23   573213523786   +573213523786       Colombia
# 60  2023-07-23   972535476707   +972535476707         Israel
#
# [1893923 rows x 4 columns]

# %%
# Especifica la ruta y el nombre del archivo CSV en tu sistema local
file_path = 'C:/Users/juanj/OneDrive/Documents/csvfiles/daubycountry.csv'

# Guarda el DataFrame en el archivo CSV
df_dau_all.to_csv(file_path, index=False)

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# Inicializa la autenticación de Google Drive
gauth = GoogleAuth()

# Carga las credenciales desde un archivo JSON que has descargado de tu proyecto en Google Cloud Platform
gauth.LocalWebserverAuth()

# Inicializa el objeto GoogleDrive
drive = GoogleDrive(gauth)

# Ruta y nombre del archivo CSV local que deseas subir
file_path = 'C:/Users/juanj/OneDrive/Documents/csvfiles/daubycountry.csv'

# Ruta en Google Drive donde deseas almacenar el archivo
remote_file_path = 'https://drive.google.com/drive/u/0/folders/1lKQU2j94FOcMnPhgB1ug_yaLmJJ2Yuyh/archivo.csv'
# Sube el archivo CSV a Google Drive
file = drive.CreateFile({'title': 'daubycountry.csv', 'parents': [{'id': '1lKQU2j94FOcMnPhgB1ug_yaLmJJ2Yuyh'}]})
file.Upload()

print('Archivo subido a Google Drive con éxito')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from pydrive.auth import GoogleAuth
#       2 from pydrive.drive import GoogleDrive
#       4 # Inicializa la autenticación de Google Drive
#
# ModuleNotFoundError: No module named 'pydrive'

# %%
# Renombra las columnas según tus requerimientos
df_dau_all.columns = ['Date', 'User_ID', 'Country','FormatedNumber']

# Calcula el número de usuarios activos por día y por país
active_users_by_day = df_dau_all.groupby(['Date', 'Country']).size().reset_index(name='ActiveUsers')

# Filtra los 10 países con mayor cantidad de usuarios
top_10_countries = active_users_by_day.groupby('Country')['ActiveUsers'].sum().nlargest(10).index.tolist()
active_users_by_day_top_10 = active_users_by_day[active_users_by_day['Country'].isin(top_10_countries)]

# Inicializa la aplicación Dash
app = dash.Dash(__name__)

# Define las opciones del filtro (países)
country_options = [{'label': country, 'value': country} for country in top_10_countries]

# Diseña la interfaz de usuario con el filtro y el gráfico
app.layout = html.Div([
    dcc.Dropdown(
        id='country-dropdown',
        options=country_options,
        value=top_10_countries[0],  # Establece el valor predeterminado
        multi=False
    ),
    dcc.Graph(id='user-activity-graph')
])

# Define una función para actualizar el gráfico según la selección del filtro
@app.callback(
    Output('user-activity-graph', 'figure'),
    Input('country-dropdown', 'value')
)
def update_graph(selected_country):
    filtered_data = active_users_by_day_top_10[active_users_by_day_top_10['Country'] == selected_country]
    fig = px.bar(filtered_data, x='Date', y='ActiveUsers', color='Country',
                 title=f'Usuarios activos por día en {selected_country}',
                 labels={'ActiveUsers': 'Usuarios Activos'})
    fig.update_layout(barmode='relative')
    return fig

# Ejecuta la aplicación Dash
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[17], line 43
#      41 # Ejecuta la aplicación Dash
#      42 if __name__ == '__main__':
# ---> 43     app.run_server(debug=True)
#
# File ~\anaconda3\Lib\site-packages\dash\dash.py:2155, in Dash.run_server(self, *args, **kwargs)
#    2149 def run_server(self, *args, **kwargs):
#    2150     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2151     future version. We recommend using `app.run` instead.
#    2152
#    2153     See `app.run` for usage information.
#    2154     """
# -> 2155     self.run(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\dash\dash.py:2053, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2050             extra_files.append(path)
#    2052 if jupyter_dash.active:
# -> 2053     jupyter_dash.run_app(
#    2054         self,
#    2055         mode=jupyter_mode,
#    2056         width=jupyter_width,
#    2057         height=jupyter_height,
#    2058         host=host,
#    2059         port=port,
#    2060         server_url=jupyter_server_url,
#    2061     )
#    2062 else:
#    2063     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File ~\anaconda3\Lib\site-packages\dash\_jupyter.py:401, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     399     display(HTML(msg))
#     400 else:
# --> 401     raise final_error
#
# File ~\anaconda3\Lib\site-packages\dash\_jupyter.py:388, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     385         raise err
#     387 try:
# --> 388     wait_for_app()
#     390     if self.in_colab:
#     391         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File ~\anaconda3\Lib\site-packages\retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\anaconda3\Lib\site-packages\retrying.py:266, in Retrying.call(self, fn, *args, **kwargs)
#     263 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     264     if not self._wrap_exception and attempt.has_exception:
#     265         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 266         raise attempt.get()
#     267     else:
#     268         raise RetryError(attempt)
#
# File ~\anaconda3\Lib\site-packages\retrying.py:301, in Attempt.get(self, wrap_exception)
#     299         raise RetryError(self)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#     303     return self.value
#
# File ~\anaconda3\Lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File ~\anaconda3\Lib\site-packages\retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     248     self._before_attempts(attempt_number)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#     253     tb = sys.exc_info()
#
# File ~\anaconda3\Lib\site-packages\dash\_jupyter.py:379, in JupyterDash.run_app.<locals>.wait_for_app()
#     377     if res != "Alive":
#     378         url = f"http://{host}:{port}"
# --> 379         raise OSError(
#     380             f"Address '{url}' already in use.\n"
#     381             "    Try passing a different port to run_server."
#     382         )
#     383 except requests.ConnectionError as err:
#     384     _get_error()
#
# OSError: Address 'http://127.0.0.1:8050' already in use.
#     Try passing a different port to run_server.

# %%
def getCountry(phone):
    try:
        phone_parsed = pn.parse(phone)
        country_code = pn.region_code_for_number(phone_parsed)
        country = pycountry.countries.get(alpha_2=country_code)
        return country.name
    except Exception as e:
        return "Error: " + str(e)
